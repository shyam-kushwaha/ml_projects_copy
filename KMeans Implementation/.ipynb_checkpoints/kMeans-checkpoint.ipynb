# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
class kmeans:
    n_clusters = 0
    X = 0
    y = 0
    
    sse = 0
    
    clusterIds = 0
    tolerance  = 1e-5
    
    trainingDone = False;
    
    history = []
    
    ## Constructor 
    def __init__(self,n):
        self.n_clusters = n
    
    def initialiseClusterCentroids(self):
        self.centroids = np.random.randint(int(np.min(self.X)),int(np.max(self.X)) ,(self.n_clusters,self.X.shape[1])).copy()
        self.clusterIds = np.random.randint(0,self.n_clusters,self.X.shape[0])
    
    def ComputeSSE(self):
        sse_ = 0
        for clust in range(self.n_clusters):
            index = np.where(self.clusterIds == clust)
            val = self.X[index]
            
            for x in val:
                sse_ += np.linalg.norm(val - self.centroids[clust],2)
        
        self.sse = sse_;
        return sse_
    
    def computeNewCentroids(self):
        newCentroids = np.zeros(np.shape(self.centroids))
        for clust in range(self.n_clusters):
            val = np.where(self.clusterIds == clust)[0]
            # print("-- clust id : ", clust)
            # print("-- Value : \n" , self.X[val])
            newCentroids[clust,:] = np.mean(self.X[val] ,axis = 0)
                # print("** K : ",newCentroids[clust][i], " orig : " , k)
            
        self.centroids = newCentroids.copy()
        # print("&&& Centroids : \n" , self.centroids)
    
    
    def assignNewClusters(self,X,clusterids):
        
        for indx,x in enumerate(X):
            dis = np.zeros(self.n_clusters)
            for index,c in enumerate(self.centroids):
                dis[index] = np.linalg.norm(x - c,2)
            
            clusterids[indx] = np.argmin(dis)
            
    
            
    def trainkMeans(self):
        Oldsse  = self.ComputeSSE();
        iteration  = 0
        residual = 100 ## entry condition
        while(residual > self.tolerance):
            self.history.append(Oldsse)
            self.computeNewCentroids();

            self.assignNewClusters(self.X,self.clusterIds)
            sse = self.ComputeSSE();
            residual = abs(Oldsse - sse)
            Oldsse = sse
            iteration  += 1;
            # print(f"At iteration :{iteration} - SSE : " , sse)
        self.trainingDone = True
        
    
    def fit(self,X):
        self.X = X.copy()
        self.centroids = np.zeros((self.n_clusters,X.shape[1]))
        self.clusterIds = np.zeros(X.shape[0])
        self.initialiseClusterCentroids()
        
        self.trainkMeans();
        self.trainingDone = True
        return self.clusterIds
    
    def predict(self,X_test):
        if(not self.trainingDone ):
            print(" Trainning not Completed ")
            return;
        pred = np.zeros(X_test.shape[0])
        self.assignNewClusters(X_test,pred)
        return pred
    
    def predictMisclassification(self,actual,pred):
        mis = []
        for clust in range(self.n_clusters):
            index  = np.where(actual == clust)[0];
            predVal = pred[index]
            indexMis = np.where(predVal != clust)[0]
            mis.append(len(indexMis))
            print("No of misclassification on Cluster " , str(clust) , " is " , len(indexMis))
        return mis
    
    def historyPlotter(self):
        plt.plot(self.history,label="sse")
        plt.title("SSE Plot")
        plt.grid()
        plt.legend()
    
    def getCentroid(self):
        for i,k in enumerate(self.centroids):
            print(f"(({k}), {i})")

# %%
### Read the data 
data = pd.read_csv("data.txt",delimiter=" ", header = None)

# %%
from sklearn.model_selection import train_test_split

X = data.iloc[:,0:2].to_numpy()
y = data.iloc[:,2].to_numpy()
X_train,X_test,y_train,y_test = train_test_split(data.iloc[:,0:2].to_numpy(),data.iloc[:,2].to_numpy(),test_size=0.2)

# %%
kmeansObj = kmeans(3)
l = kmeansObj.fit(X)
centroid = kmeansObj.centroids

prediction_y = kmeansObj.predict(X)
predRate = [len(np.where(prediction_y == x)[0]) for x in range(3)]

# %%
from itertools import permutations
from sklearn.metrics import accuracy_score

def accuracyComputation(original,predicted):
    size = len(set(original))
    kk = ''
    for i in set(range(0,size)):
        kk += str(i)
    perms = [''.join(p) for p in permutations(kk)]
    
    ACCURACYSCORE = []
    ACCURACYARRAY = []
    ACCURACYSCORE.append(accuracy_score(original,predicted))
    
    predCopy = np.array(predicted).copy()
    ACCURACYARRAY.append(accuracy_score(original,predCopy))
    ## iterate through all permutations
    for index,per in enumerate(perms):
        predCopy = np.array(predicted).copy()
        if(index ==0): continue;
        replaceDict = {}
        for i,char in enumerate(per):
            replaceDict[i] = int(char)
        
        for i,val in enumerate(predCopy):
            predCopy[i] = replaceDict[val] 
        
        acc = accuracy_score(original,predCopy)
        ACCURACYSCORE.append(acc)
        ACCURACYARRAY.append(predCopy)
    
    return np.max(ACCURACYSCORE),ACCURACYARRAY[np.argmax(ACCURACYSCORE)]

# %%
print("===========================================================================")
print("===================== KMEANS CLUSTERS ====================================")
print("===========================================================================")
kmeansObj.getCentroid()
accuracy, bestPrediction  = accuracyComputation(y,prediction_y)
# Out:
# ===========================================================================
# ===================== KMEANS CLUSTERS ====================================
# ===========================================================================
# (([ 7.43650602 15.10843373]), 0)
# (([5.206      9.78680952]), 1)
# (([10.74524194 10.75040323]), 2)

# %%
print("===========================================================================")
print("===================== NUMBER IN EACH  CLUSTERS =============================")
print("===========================================================================")
for i,k in enumerate(predRate):
    print(f"Size of Cluster {i} : {k}")
# Out:
# ===========================================================================
# ===================== NUMBER IN EACH  CLUSTERS =============================
# ===========================================================================
# Size of Cluster 0 : 166
# Size of Cluster 1 : 210
# Size of Cluster 2 : 124

# %%
print("===========================================================================")
print("===================== MISCLASSIFICATION DETAILS ===========================")
print("===========================================================================")
misRate = kmeansObj.predictMisclassification(y_test,bestPrediction)
# Out:
# ===========================================================================
# ===================== MISCLASSIFICATION DETAILS ===========================
# ===========================================================================
# No of misclassification on Cluster  0  is  0
# No of misclassification on Cluster  1  is  32
# No of misclassification on Cluster  2  is  23

# %%
print("===========================================================================")
print("===================== CLUSTER PRINTOUT         ===========================")
print("===========================================================================")

for clust in range(0,3):
    index = np.where(bestPrediction == clust)[0]
    
    print("*****************************************")
    print(f"*** Cluster No : {clust} ***************")
    print("*****************************************")
    
    for i in index:
        print(f"Point : {X[i]} , Actual : {y[i]}")
# Out:
# ===========================================================================
# ===================== CLUSTER PRINTOUT         ===========================
# ===========================================================================
# *****************************************
# *** Cluster No : 0 ***************
# *****************************************
# Point : [5.94 8.54] , Actual : 0
# Point : [ 3.6  10.52] , Actual : 0
# Point : [ 4.32 11.34] , Actual : 0
# Point : [ 5.37 12.05] , Actual : 0
# Point : [3.98 7.44] , Actual : 0
# Point : [ 4.93 10.21] , Actual : 0
# Point : [ 5.18 10.14] , Actual : 0
# Point : [4.17 5.85] , Actual : 0
# Point : [3.69 8.27] , Actual : 0
# Point : [ 5.19 10.06] , Actual : 0
# Point : [5.99 6.44] , Actual : 0
# Point : [ 4.35 10.75] , Actual : 0
# Point : [ 4.67 12.59] , Actual : 0
# Point : [6.65 7.41] , Actual : 0
# Point : [ 4.44 12.93] , Actual : 0
# Point : [7.4  9.44] , Actual : 0
# Point : [3.47 9.38] , Actual : 0
# Point : [5.8 9.1] , Actual : 0
# Point : [3.   4.18] , Actual : 0
# Point : [4.4  7.54] , Actual : 0
# Point : [ 6.5  11.74] , Actual : 0
# Point : [6.22 9.44] , Actual : 0
# Point : [ 4.1  11.27] , Actual : 0
# Point : [4.55 9.97] , Actual : 0
# Point : [5.08 9.87] , Actual : 0
# Point : [ 3.74 11.08] , Actual : 0
# Point : [5.55 7.8 ] , Actual : 0
# Point : [ 7.23 10.82] , Actual : 0
# Point : [ 3.64 10.58] , Actual : 0
# Point : [3.02 7.59] , Actual : 0
# Point : [5.29 6.72] , Actual : 0
# Point : [4.88 8.96] , Actual : 0
# Point : [ 4.95 12.31] , Actual : 0
# Point : [4.81 9.34] , Actual : 0
# Point : [ 4.01 10.5 ] , Actual : 0
# Point : [5.67 9.66] , Actual : 0
# Point : [ 3.68 12.17] , Actual : 0
# Point : [ 6.17 11.05] , Actual : 0
# Point : [5.01 6.16] , Actual : 0
# Point : [ 5.5  11.62] , Actual : 0
# Point : [ 4.45 11.8 ] , Actual : 0
# Point : [4.08 8.92] , Actual : 0
# Point : [6.8 8.5] , Actual : 0
# Point : [ 5.47 11.12] , Actual : 0
# Point : [6.21 8.84] , Actual : 0
# Point : [ 5.19 10.57] , Actual : 0
# Point : [ 7.61 10.07] , Actual : 0
# Point : [5.36 8.93] , Actual : 0
# Point : [3.97 7.68] , Actual : 0
# Point : [5.43 8.44] , Actual : 0
# Point : [ 2.68 10.49] , Actual : 0
# Point : [4.88 9.69] , Actual : 0
# Point : [5.98 9.98] , Actual : 0
# Point : [5.8  6.89] , Actual : 0
# Point : [4.66 8.23] , Actual : 0
# Point : [3.79 7.38] , Actual : 0
# Point : [ 5.49 12.34] , Actual : 0
# Point : [3.85 8.36] , Actual : 0
# Point : [6.32 8.27] , Actual : 0
# Point : [ 4.69 11.79] , Actual : 0
# Point : [ 4.08 10.7 ] , Actual : 0
# Point : [ 4.43 12.57] , Actual : 0
# Point : [ 4.19 11.14] , Actual : 0
# Point : [ 4.44 10.06] , Actual : 0
# Point : [4.26 8.23] , Actual : 0
# Point : [ 4.62 13.06] , Actual : 0
# Point : [5.24 9.64] , Actual : 0
# Point : [5.6  8.22] , Actual : 0
# Point : [3.89 9.58] , Actual : 0
# Point : [4.05 9.6 ] , Actual : 0
# Point : [ 4.57 12.92] , Actual : 0
# Point : [5.1  9.51] , Actual : 0
# Point : [ 2.96 11.94] , Actual : 0
# Point : [6.7  8.41] , Actual : 0
# Point : [4.11 9.5 ] , Actual : 0
# Point : [6.82 8.53] , Actual : 0
# Point : [ 3.65 10.2 ] , Actual : 0
# Point : [ 4.04 11.2 ] , Actual : 0
# Point : [ 4.75 10.38] , Actual : 0
# Point : [4.78 9.24] , Actual : 0
# Point : [4.23 9.89] , Actual : 0
# Point : [5.73 8.54] , Actual : 0
# Point : [ 3.2  11.02] , Actual : 0
# Point : [6.06 9.21] , Actual : 0
# Point : [ 4.18 10.47] , Actual : 0
# Point : [ 6.25 11.9 ] , Actual : 0
# Point : [4.59 8.77] , Actual : 0
# Point : [ 3.6  12.96] , Actual : 0
# Point : [5.45 5.4 ] , Actual : 0
# Point : [7.23 8.73] , Actual : 0
# Point : [ 4.95 11.9 ] , Actual : 0
# Point : [5.11 9.34] , Actual : 0
# Point : [4.6 8. ] , Actual : 0
# Point : [4.12 8.96] , Actual : 0
# Point : [ 4.25 13.09] , Actual : 0
# Point : [ 3.68 13.54] , Actual : 0
# Point : [3.59 7.23] , Actual : 0
# Point : [5.07 8.64] , Actual : 0
# Point : [6.62 8.61] , Actual : 0
# Point : [5.47 9.55] , Actual : 0
# Point : [ 5.25 10.77] , Actual : 0
# Point : [ 4.14 10.34] , Actual : 0
# Point : [ 5.19 10.  ] , Actual : 0
# Point : [4.58 9.29] , Actual : 0
# Point : [ 5.94 12.  ] , Actual : 0
# Point : [ 6.23 10.1 ] , Actual : 0
# Point : [6.25 7.83] , Actual : 0
# Point : [5.37 9.74] , Actual : 0
# Point : [6.04 7.35] , Actual : 0
# Point : [ 4.34 10.19] , Actual : 0
# Point : [4.9 9.1] , Actual : 0
# Point : [4.79 8.11] , Actual : 0
# Point : [4.1  5.96] , Actual : 0
# Point : [4.12 9.76] , Actual : 0
# Point : [3.08 8.29] , Actual : 0
# Point : [ 7.04 10.79] , Actual : 0
# Point : [ 5.05 11.56] , Actual : 0
# Point : [5.62 8.72] , Actual : 0
# Point : [4.84 5.87] , Actual : 0
# Point : [5.49 7.13] , Actual : 0
# Point : [ 5.48 10.9 ] , Actual : 0
# Point : [ 5.74 11.48] , Actual : 0
# Point : [ 2.77 11.37] , Actual : 0
# Point : [ 6.04 10.16] , Actual : 0
# Point : [ 5.15 10.57] , Actual : 0
# Point : [ 5.62 11.32] , Actual : 0
# Point : [5.46 9.55] , Actual : 0
# Point : [ 5.26 10.81] , Actual : 0
# Point : [ 6.42 11.06] , Actual : 0
# Point : [4.63 8.19] , Actual : 0
# Point : [ 5.51 11.74] , Actual : 0
# Point : [ 7.4  11.13] , Actual : 0
# Point : [6.77 9.88] , Actual : 0
# Point : [5.29 7.49] , Actual : 0
# Point : [ 8.66 15.01] , Actual : 2
# Point : [ 7.08 14.97] , Actual : 2
# Point : [ 6.09 14.47] , Actual : 2
# Point : [ 7.84 13.89] , Actual : 2
# Point : [ 7.57 15.27] , Actual : 2
# Point : [ 8.71 13.37] , Actual : 2
# Point : [ 7.17 14.47] , Actual : 2
# Point : [ 6.85 13.75] , Actual : 2
# Point : [ 6.93 13.21] , Actual : 2
# Point : [ 6.91 14.67] , Actual : 2
# Point : [ 8.36 20.3 ] , Actual : 2
# Point : [ 9.1  14.28] , Actual : 2
# Point : [ 6.66 15.66] , Actual : 2
# Point : [ 7.21 17.5 ] , Actual : 2
# Point : [ 7.31 12.48] , Actual : 2
# Point : [ 7.38 19.62] , Actual : 2
# Point : [ 8.19 17.36] , Actual : 2
# Point : [ 8.23 13.79] , Actual : 2
# Point : [ 8.68 14.43] , Actual : 2
# Point : [ 7.32 12.03] , Actual : 2
# Point : [ 8.29 18.55] , Actual : 2
# Point : [ 7.84 16.45] , Actual : 2
# Point : [ 5.81 13.94] , Actual : 2
# Point : [ 6.1 15. ] , Actual : 2
# Point : [ 6.85 14.73] , Actual : 2
# Point : [ 7.87 16.04] , Actual : 2
# Point : [ 8.18 16.82] , Actual : 2
# Point : [ 5.95 14.44] , Actual : 2
# Point : [ 6.69 13.76] , Actual : 2
# Point : [ 8.56 13.75] , Actual : 2
# Point : [ 6.02 15.55] , Actual : 2
# Point : [ 8.98 15.09] , Actual : 2
# Point : [ 8.69 14.99] , Actual : 2
# Point : [ 6.57 15.38] , Actual : 2
# Point : [ 7.34 15.46] , Actual : 2
# Point : [ 7.35 18.24] , Actual : 2
# Point : [ 7.54 18.27] , Actual : 2
# Point : [ 7.77 17.17] , Actual : 2
# Point : [ 8.93 14.27] , Actual : 2

# %%
print("===========================================================================")
print("===================== ACCURACY DETAILS ====================================")
print("===========================================================================")
accuracy, bestPrediction  = accuracyComputation(y,prediction_y)
print("Accuracy of Model is " , accuracy)
# Out:
# ===========================================================================
# ===================== ACCURACY DETAILS ====================================
# ===========================================================================
# Accuracy of Model is  0.884

# %%
fig, ax = plt.subplots(1,2,figsize=(10,4))

ax[0].bar(['0','1','2'],misRate,color="red")
ax[0].set_title("MisClassification")
ax[0].set_xlabel("Class")
ax[0].set_ylabel("MisClassification")
ax[0].set_ylim([0,220])

ax[1].bar(['0','1','2'],predRate,color='green')
ax[1].set_title("Classification")
ax[1].set_xlabel("Class")
ax[1].set_ylabel("Classification Metrics")
ax[1].set_ylim([0,220])
# Out:
# (0.0, 220.0)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2,figsize=(12,4))

ax[0].scatter(X[:,0],X[:,1],c=prediction_y )
ax[0].scatter(centroid[:,0],centroid[:,1] )
ax[0].set_title("Actual Labels")

ax[1].scatter(X[:,0],X[:,1],c=bestPrediction )
ax[1].scatter(centroid[:,0],centroid[:,1] )
ax[1].set_title("Actual Labels")
# Out:
# Text(0.5, 1.0, 'Actual Labels')
